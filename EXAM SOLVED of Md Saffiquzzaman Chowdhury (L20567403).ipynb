# %% [markdown]
# <H1>MD SAFFIQUZZAMAN CHOWDHURY (L20567403)
# EXAM ANSWERS</H1>

# %% [markdown]
# <H2>ANSWER 2 SOLVE</H2>

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# <H2>DATASET FROM US CENSUSU BUREAU FOR THE YEARS 2010-2020</H2>

# %%
Og = pd.read_csv('C:\\Users\\siamb\\Downloads\\Ques 2 Data File (Md Saffiquzzaman Chowdhury).csv')
Og
# Out:
#    table with row headers in column A and column headers in rows 3 through 4. (leading dots indicate sub-parts)  \
# 0   Annual Estimates of the Resident Population fo...
# 1                                     Geographic Area
# 2                                                 NaN
# 3                                       United States
# 4                                 Suggested Citation:
# ..                                                ...
# 58                                                NaN
# 59                                                NaN
# 60                                                NaN
# 61                                                NaN
# 62                                                NaN
#
#        Unnamed: 1      Unnamed: 2                          Unnamed: 3  \
# 0             NaN             NaN                                 NaN
# 1   April 1, 2010             NaN  Population Estimate (as of July 1)
# ...

# %% [markdown]
# !![Screenshot%20%28255%29.png](attachment:Screenshot%20%28255%29.png)

# %%
x1=[2010,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2020] #year
y1=[308745538,309327143,311583481,313877662,316059947,318386329,320738994,323071755,325122128,326838199,328329953,329398742,329484123]  #population



plt.plot(x1,y1, color='blue')


plt.xlabel("Year") #year data
plt.ylabel("Population") #population data
plt.legend()
plt.title('Population vs Years')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# Data Link: https://www.census.gov/programs-surveys/popest/technical-documentation/research/evaluation-estimates/2020-evaluation-estimates/2010s-state-total.html

# %% [markdown]
# <h3>Answer 1</h3>

# %%
# Defining Function
def f(D):
    return D*****3 - 12*D****4 + 16*q**2/(π**2*Cd**2*g)

# Defining derivative of function
def g(x):
    return 3*D**2 - 48*D***3 + 32*q/(2*π*2Cd*g)
# Implementing Newton Raphson Method

def newtonRaphson(x0,e,N):
    print('\n\n*** NEWTON RAPHSON METHOD IMPLEMENTATION ***')
    step = 1
    flag = 1
    condition = True
    while condition:
        if g(x0) == 0.0:
            print('Divide by zero error!')
            break
        
        D = D - f(x0)/g(x0)
        print('Iteration-%d, x1 = %0.6f and f(x1) = %0.6f' % (step, x1, f(x1)))
        x0 = x1
        step = step + 1
        
        if step > N:
            flag = 0
            break
        
        condition = abs(f(x1)) > e
    
    if flag==1:
        print('\nRequired root is: %0.8f' % x1)
    else:
        print('\nNot Convergent.')


# Input Section
x0 = input('Enter Guess: ')
e = input('Tolerable Error: ')
N = input('Maximum Step: ')

# Converting x0 and e to float
x0 = float(x0)
e = float(e)

# Converting N to integer
N = int(N)




# Starting Newton Raphson Method
newtonRaphson(x0,e,N)
